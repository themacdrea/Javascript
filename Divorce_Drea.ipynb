# %%
import pandas as pd
from datetime import datetime

# %%
divorce_df = pd.read_csv("archive\divorces_2000-2015_translated.csv")

# %%
divorce_df
# Out:
#      Divorce_date Type_of_divorce Nationality_partner_man DOB_partner_man  \
# 0          9/6/06       Necesario                MEXICANA        18/12/75
# 1          1/2/00      Voluntario                MEXICANA             NaN
# 2          1/2/05       Necesario                MEXICANA         22/2/55
# 3          1/2/06       Necesario                MEXICANA         20/1/64
# 4          1/2/06       Necesario                MEXICANA        30/10/75
# ...           ...             ...                     ...             ...
# 4918     31/10/12      Voluntario                MEXICANA        29/10/77
# 4919     31/10/13      Voluntario                MEXICANA        10/11/82
# 4920     31/10/13      Voluntario                MEXICANA        28/10/54
# 4921     31/12/12      Voluntario                MEXICANA          7/2/58
# 4922     31/12/13      Voluntario                MEXICANA         22/6/60
#
#      Place_of_birth_partner_man Birth_municipality_of_partner_man  \
# ...

# %%
# Remove unwanted columns
remove = ['Place_of_birth_partner_man',
'Birth_municipality_of_partner_man',
'Birth_federal_partner_man',
'Birth_country_partner_man', 
'Residence_municipality_partner_man',
'Residence_federal_partner_man',
'Residence_country_partner_man',  
'Place_of_residence_partner_man',
'DOB_registration_date_partner_woman',
'Place_of_birth_partner_woman',
'Birth_municipality_of_partner_woman',
'Birth_federal_partner_woman',
'Birth_country_partner_woman',
'Place_of_residence_partner_woman',
'Residence_municipality_partner_woman',
'Residence_federal_partner_woman',
'Residence_country_partner_woman', 
'Marriage_certificate_place',
'Marriage_certificate_municipality',
'Marriage_certificate_federal',
'Marriage_duration_months',
'Custody']

divorce_df = divorce_df.drop(columns=remove)
divorce_df.head()
# Out:
#   Divorce_date Type_of_divorce Nationality_partner_man DOB_partner_man  \
# 0       9/6/06       Necesario                MEXICANA        18/12/75
# 1       1/2/00      Voluntario                MEXICANA             NaN
# 2       1/2/05       Necesario                MEXICANA         22/2/55
# 3       1/2/06       Necesario                MEXICANA         20/1/64
# 4       1/2/06       Necesario                MEXICANA        30/10/75
#
#    Age_partner_man  Monthly_income_partner_man_peso Occupation_partner_man  \
# 0             30.0                           2000.0                 PINTOR
# 1             47.0                              NaN                    NaN
# 2             49.0                              NaN                 MEDICO
# 3             42.0                           6000.0               EMPLEADO
# 4             30.0                          18000.0                 MEDICO
#
#   Nationality_partner_woman DOB_partner_woman  Age_partner_woman  \
# ...

# %%
divorce_df.dropna(inplace=True)

# Reset the index after removing rows
divorce_df.reset_index(drop=True, inplace=True)
divorce_df
# Out:
#      Divorce_date Type_of_divorce Nationality_partner_man DOB_partner_man  \
# 0          9/6/06       Necesario                MEXICANA        18/12/75
# 1          1/2/11       Necesario                MEXICANA          4/6/69
# 2          1/3/05       Necesario                MEXICANA          9/7/70
# 3          1/3/05       Necesario                MEXICANA          7/2/74
# 4          1/3/06       Necesario                MEXICANA          3/4/64
# ...           ...             ...                     ...             ...
# 1370     31/10/00      Voluntario                MEXICANA          3/9/59
# 1371     31/10/01      Voluntario                MEXICANA        20/11/62
# 1372     31/10/01      Voluntario                MEXICANA          4/7/58
# 1373     31/10/02      Voluntario                MEXICANA         18/8/51
# 1374     31/10/13      Voluntario                MEXICANA        28/10/54
#
#       Age_partner_man  Monthly_income_partner_man_peso Occupation_partner_man  \
# ...

# %%
divorce_df.columns.to_list()
# Out:
# ['Divorce_date',
#  'Type_of_divorce',
#  'Nationality_partner_man',
#  'DOB_partner_man',
#  'Age_partner_man',
#  'Monthly_income_partner_man_peso',
#  'Occupation_partner_man',
#  'Nationality_partner_woman',
#  'DOB_partner_woman',
#  'Age_partner_woman',
#  'Occupation_partner_woman',
#  'Monthly_income_partner_woman_peso',
#  'Date_of_marriage',
#  'Level_of_education_partner_man',
#  'Employment_status_partner_man',
#  'Level_of_education_partner_woman',
#  'Employment_status_partner_woman',
#  'Marriage_duration',
#  'Num_Children']

# %%
columns = ['Divorce_date',
 'Type_of_divorce',
 'Nationality_partner_man',
 'DOB_partner_man',
 'Age_partner_man',
 'Monthly_income_partner_man_peso',
 'Occupation_partner_man',
 'Nationality_partner_woman',
 'DOB_partner_woman',
 'Age_partner_woman',
 'Occupation_partner_woman',
 'Monthly_income_partner_woman_peso',
 'Date_of_marriage',
 'Level_of_education_partner_man',
 'Employment_status_partner_man',
 'Level_of_education_partner_woman',
 'Employment_status_partner_woman',
 'Marriage_duration',
 'Num_Children']

for col in columns:
    total_nulls = divorce_df[col].isnull().sum()
print("Total null values in column '{}' are: {}".format(columns, total_nulls))
# Out:
# Total null values in column '['Divorce_date', 'Type_of_divorce', 'Nationality_partner_man', 'DOB_partner_man', 'Age_partner_man', 'Monthly_income_partner_man_peso', 'Occupation_partner_man', 'Nationality_partner_woman', 'DOB_partner_woman', 'Age_partner_woman', 'Occupation_partner_woman', 'Monthly_income_partner_woman_peso', 'Date_of_marriage', 'Level_of_education_partner_man', 'Employment_status_partner_man', 'Level_of_education_partner_woman', 'Employment_status_partner_woman', 'Marriage_duration', 'Num_Children']' are: 0

# %%
# Create a new column with id number 
divorce_df.insert(0, 'Id', range(1, len(divorce_df)+1))
divorce_df.head()
# Out:
#    Id Divorce_date Type_of_divorce Nationality_partner_man DOB_partner_man  \
# 0   1       9/6/06       Necesario                MEXICANA        18/12/75
# 1   2       1/2/11       Necesario                MEXICANA          4/6/69
# 2   3       1/3/05       Necesario                MEXICANA          9/7/70
# 3   4       1/3/05       Necesario                MEXICANA          7/2/74
# 4   5       1/3/06       Necesario                MEXICANA          3/4/64
#
#    Age_partner_man  Monthly_income_partner_man_peso Occupation_partner_man  \
# 0             30.0                           2000.0                 PINTOR
# 1             41.0                           5000.0            COMERCIANTE
# 2             34.0                           5600.0                 CHOFER
# 3             31.0                           3500.0               EMPLEADO
# 4             41.0                          12000.0            COMERCIANTE
#
# ...

# %%
#Rename columns
column_names = {
    'Divorce_date': 'Divorce Date',
    'Type_of_divorce': 'Divorce Type',
    'Nationality_partner_man': 'Nationality Male',
    'DOB_partner_man': 'DOB Male',
    'Age_partner_man': 'Age Male',
    'Monthly_income_partner_man_peso': 'Income Male',
    'Occupation_partner_man': 'Occupation Male',
    'Nationality_partner_woman': 'Nationality Female',
    'DOB_partner_woman': 'DOB Female',
    'Age_partner_woman': 'Age Female',
    'Occupation_partner_woman': 'Occupation Female',
    'Monthly_income_partner_woman_peso': 'Income Female',
    'Date_of_marriage': 'Marriage Date',
    'Level_of_education_partner_man': 'Education Male',
    'Employment_status_partner_man': 'Employment Male',
    'Level_of_education_partner_woman': 'Education Female',
    'Employment_status_partner_woman': 'Employment Female',
    'Marriage_duration': 'Marriage Year',
    'Marriage_duration_months': 'Marriage Months',
    'Num_Children': 'Number Children',
    'Custody': 'Custody'
}

divorce_df = divorce_df.rename(columns=column_names)
divorce_df.head()
# Out:
#    Id Divorce Date Divorce Type Nationality Male  DOB Male  Age Male  \
# 0   1       9/6/06    Necesario         MEXICANA  18/12/75      30.0
# 1   2       1/2/11    Necesario         MEXICANA    4/6/69      41.0
# 2   3       1/3/05    Necesario         MEXICANA    9/7/70      34.0
# 3   4       1/3/05    Necesario         MEXICANA    7/2/74      31.0
# 4   5       1/3/06    Necesario         MEXICANA    3/4/64      41.0
#
#    Income Male Occupation Male Nationality Female DOB Female  Age Female  \
# 0       2000.0          PINTOR           MEXICANA     8/1/83        22.0
# 1       5000.0     COMERCIANTE           MEXICANA    16/2/70        40.0
# 2       5600.0          CHOFER           MEXICANA    25/5/69        35.0
# 3       3500.0        EMPLEADO           MEXICANA    19/3/67        37.0
# 4      12000.0     COMERCIANTE           MEXICANA    20/8/76        29.0
#
#   Occupation Female  Income Female Marriage Date Education Male  \
# ...

# %%
divorce_df.columns.to_list()
# Out:
# ['Id',
#  'Divorce Date',
#  'Divorce Type',
#  'Nationality Male',
#  'DOB Male',
#  'Age Male',
#  'Income Male',
#  'Occupation Male',
#  'Nationality Female',
#  'DOB Female',
#  'Age Female',
#  'Occupation Female',
#  'Income Female',
#  'Marriage Date',
#  'Education Male',
#  'Employment Male',
#  'Education Female',
#  'Employment Female',
#  'Marriage Year',
#  'Number Children']

# %%
divorce_df['DOB Male'] = pd.to_datetime(divorce_df['DOB Male'])

# Clean up the DOB column to the format 'y/m/d'
divorce_df['DOB Male'] = divorce_df['DOB Male'].dt.strftime('%Y/%m/%d')

drop_null_male = 'DOB Male'
divorce_df.dropna(subset=[drop_null_male], inplace=True)

divorce_df['DOB Female'] = pd.to_datetime(divorce_df['DOB Female'])

# Clean up the DOB column to the format 'y/m/d'
divorce_df['DOB Female'] = divorce_df['DOB Female'].dt.strftime('%Y/%m/%d')

drop_null_female = 'DOB Female'
divorce_df.dropna(subset=[drop_null_female], inplace=True)

# %%
columns = ['Id',
 'Divorce Date',
 'Divorce Type',
 'Nationality Male',
 'DOB Male',
 'Age Male',
 'Income Male',
 'Occupation Male',
 'Nationality Female',
 'DOB Female',
 'Age Female',
 'Occupation Female',
 'Income Female',
 'Marriage Date',
 'Education Male',
 'Employment Male',
 'Education Female',
 'Employment Female',
 'Marriage Year',
 'Number Children']

for col in columns:
    print(divorce_df[col].unique())
# Out:
# [   1    2    3 ... 1373 1374 1375]
# ['9/6/06' '1/2/11' '1/3/05' ... '31/10/01' '31/10/02' '31/10/13']
# ['Necesario' 'Voluntario']
# ['MEXICANA' 'FRANCESA' 'ESTADOUNIDENSE' 'ITALIANA' 'ALEMANA' 'ESPAÑOLA']
# ['1975/12/18' '2069/04/06' '2070/09/07' ... '2058/04/07' '2051/08/18'
#  '2054/10/28']
# [30. 41. 34. 31. 37. 45. 33. 43. 53. 40. 35. 32. 36. 27. 38. 59. 64. 42.
#  47. 26. 24. 49. 39. 55. 50. 44. 51. 48. 63. 25. 54. 46. 29. 28. 52. 57.
#  56. 66. 61. 58. 67. 60. 62. 23. 70. 22. 69. 72. 20. 65. 21.]
# [2.000000e+03 5.000000e+03 5.600000e+03 3.500000e+03 1.200000e+04
#  6.000000e+03 1.400000e+04 1.000000e+04 8.000000e+03 2.200000e+03
#  3.000000e+03 3.900000e+03 2.500000e+04 6.500000e+03 8.400000e+03
#  9.000000e+03 1.000000e+03 2.400000e+03 4.000000e+03 1.800000e+04
#  2.500000e+03 7.000000e+03 1.500000e+04 4.123620e+05 2.000000e+04
#  1.900000e+04 4.000000e+04 1.560000e+04 5.400000e+03 3.000000e+04
#  2.240000e+03 1.600000e+04 4.800000e+03 1.085600e+04 4.500000e+03
# ...

# %%
#replace spanish
spanish = ['Necesario','Voluntario',
'MEXICANA','FRANCESA','ESTADOUNIDENSE','ITALIANA','ALEMANA','ESPAÑOLA',
'PINTOR','COMERCIANTE','CHOFER','EMPLEADO','ING. CIVIL','COMUNICOLOGO'
,'FERROCARRILERO','PUBLICISTA','ING.','CIRUJANO DENTISTA','MAESTRO'
,'MEDICO VETERINARIO','MEDICO JUBILADO','ABOGADO','TAXISTA','PROFESOR'
,'AGENTE DE SEGUROS','PRODUCTOR','MEDICO CIRUJANO','MEDICO','MECANICO'
,'CHEF','EMPLEADO FEDERAL','ARQUITECTO','CERRAJERO','DISEÑADOR'
,'CONTADOR','INFORMATICO','BIOLOGO','LIC. EN DERECHO','FITOTERAPEUTA'
,'EMPRESARIO','OBRERO','DECORADOR','FUNCIONARIO','EMPLEADO DE GOBIERNO'
,'DOCENTE','GINECOLOGO','LICENCIADO','JUBILADO','CATEDRATICO','FONTANERO'
,'EBANISTA','ALBAÑIL','OPERADOR','ING. AGRONOMO','CARPINTERO','TECNICO'
,'LOCUTOR','LITIGANTE','RADIO TECNICO','FOTOGRAFO','AUXILIAR,CONTABLE'
,'MUSICO','TOPOGRAFO','PSICOLOGO','CAMPESINO','DENTISTA','VETERINARIO'
,'PATRON','ESCRITOR','SASTRE','ODONTOLOGO','HOJALATERO','ENTRENADOR'
,'TRANSPORTISTA','ACADEMICO','ASESOR','INVESTIGADOR','MEDICO GENERAL'
,'ELECTRICISTA','POLICIA','ELECTROMECANICO','TECNICO EN ELECTRONICA'
,'PENSIONADO','GANADERO','ENFERMERO','TRANSITO','PILOTO AVIADOR'
,'EMPLEADO BANCARIO','CONTADOR PUBLICO','ALUMINIERO','AGRICULTOR'
,'ANTROPOLOGO','EJECUTIVO','AGENTE DE VENTAS'
,'LIC. ADMINISTRACION EMPRESAS','RELOJERO','CONSTRUCTOR','VENDEDOR'
,'PLOMERO','EMPLEADO,DE,PEMEX','AGRONOMO','LIC.,EN,EDUCACION','PASTOR'
,'CONDUCTOR','MILITAR','REPRESENTANTE,DE,VENTAS','REPORTERO','ESTILISTA'
,'GERENTE','SUPERVISOR','NUTRIOLOGO','ARTE,AUTOPCIA','PROFESIONISTA'
,'CONTRATISTA','VIGILANTE','PEDIATRA','ECONOMISTA','TECNICO,ELECTRICISTA'
,'EMPRESARIO CUENTA PROPIA','CONCESIONARIO','SERVIDOR,PUBLICO','ACTOR'
,'PUBLICIDAD','LIC. INFORMATICA','VELADOR','FUNCIONARIO,PRIVADO'
,'IMPRESOR','QUIMICO','MENTOR','DOCTOR',
'MEXICANA','FRANCESA','ESTADOUNIDENSE','POLACA','CUBANA','BRITANICA',
'EMPLEADA','EMPLEADO','LABORES,DOMESTICAS','PROFESORA','DISEÑADORA'
,'SECRETARIA','ESTILISTA','DOCENTE','CONTADORA','COMERCIANTE'
,'AMA DE CASA','ARQUITECTA','MAESTRA','LICENCIADA','ODONTOLOGA'
,'ENFERMERA','EMPRESARIA','MEDICO','PERIODISTA','PUBILISTA','DENTISTA'
,'JUBILADA','EDUCADORA','CATEDRATICA','PSICOLOGA','CONTADOR,PUBLICO'
,'CAJERA','EMPLEADA DE GOBIERNO','ADMINISTRADORA','CIRUJANO DENTISTA'
,'CANTANTE','ABOGADA','PROFESORA PREESCOLAR','COCINERA','PROFESIONISTA'
,'ESTUDIANTE','ASESORA','QUIMICA','MODESTA','DOCTORA','INGENIERA'
,'INVESTIGADORA','CULTORA DE BELLEZA','DISEÑADORA GRAFICA','PROMOTORA'
,'TERAPEUTA CORPORAL','ING. QUIMICO','CAPTURISTA','LIC. EN DERECHO'
,'COMUNICOLOGA','COSTURERA','PEDAGOGA','AGRONOMO'
,'INSTRUCTORA DE NATACION','AYUDANTE','BIOLOGA','AUXILIAR','MERCADOTECNIA'
,'GERENTE','PENSIONADA','ASISTENTE EJECUTIVA','PROFESORA DE PRIMARIA'
,'RESTAURADORA','ASISTENTE','DIRECTORA','MEDICO CIRUJANO','NUTRIOLOGA'
,'MESERA','MUSICO','AGENTE COMERCIAL','MAESTRIA','CONSULTORA'
,'QUIMICO CLINICO','TAXISTA','PUBLICISTA','TECNICO','EMPLEADA FEDERAL'
,'LIC. EN INFORMATICA','FOTOGRAFA','DEMOSTRADORA','ARTESANA'
,'LABORES DEL HOGAR','PODOLOGA','VENDEDORA','SERVIDOR PUBLICO'
,'LIC. EN IDIOMAS','ACADEMICA','FUNCIONARIO,PUBLICO','MENTORA'
'SECUNDARIA','PREPARATORIA','PROFESIONAL','PRIMARIA','SIN ESCOLARIDAD'
,'OTRO','OBRERO','ESTABLECIMIENTO','EMPLEADO','PATRON O EMPRESARIO','TRABAJADOR POR SU PROPIA CUENTA O EN VIA PUBLICA','NO TRABAJA','TRABAJA EN SU VIVIENDA','MIEMBRO DE COOPERATIVA','JORNALERO O PEON'
'SECUNDARIA','PROFESIONAL','PREPARATORIA','PRIMARIA','OTRO'
'EMPLEADO','ESTABLECIMIENTO','NO TRABAJA','PATRON O EMPRESARIO'
,'TRABAJADOR POR CUENTA PROPIA EN VIA PUBLICA','TRABAJA EN SU VIVIENDA'
,'OBRERO','MIEMBRO DE COOPERATIVA','TRABAJADOR NO REMUNERADO']

# %%
english = [
    'Necessary', 'Voluntary', 'Mexican', 'French', 'American', 'Italian', 'German', 'Spanish',
    'Painter', 'Merchant', 'Driver', 'Employee', 'Civil Engineer', 'Communicologist', 'Railway Worker',
    'Publicist', 'Engineer', 'Dentist Surgeon', 'Teacher', 'Veterinarian', 'Retired Doctor', 'Lawyer',
    'Taxi Driver', 'Professor', 'Insurance Agent', 'Producer', 'Surgeon Doctor', 'Doctor', 'Mechanic',
    'Chef', 'Federal Employee', 'Architect', 'Locksmith', 'Designer', 'Accountant', 'Computer Scientist',
    'Biologist', 'Law Graduate', 'Herbalist', 'Entrepreneur', 'Worker', 'Decorator', 'Official',
    'Government Employee', 'Teacher', 'Gynecologist', 'Graduate', 'Retired', 'Professor', 'Plumber',
    'Carpenter', 'Operator', 'Agricultural Engineer', 'Technician', 'Announcer', 'Litigator',
    'Radio Technician', 'Photographer', 'Assistant Accountant', 'Musician', 'Surveyor', 'Psychologist',
    'Farmer', 'Dentist', 'Veterinarian', 'Employer', 'Writer', 'Tailor', 'Dentist', 'Tinsmith',
    'Trainer', 'Transporter', 'Academic', 'Advisor', 'Researcher', 'General Practitioner', 'Electrician',
    'Police Officer', 'Electromechanic', 'Electronics Technician', 'Pensioner', 'Rancher', 'Nurse',
    'Transit Officer', 'Pilot', 'Bank Employee', 'Certified Accountant', 'Aluminum Worker', 'Farmer',
    'Anthropologist', 'Executive', 'Sales Agent', 'Business Administration Graduate', 'Watchmaker',
    'Builder', 'Salesperson', 'Plumber', 'PEMEX Employee', 'Agronomist', 'Education Graduate', 'Pastor',
    'Driver', 'Military', 'Sales Representative', 'Reporter', 'Hairdresser', 'Manager', 'Supervisor',
    'Nutritionist', 'Autopsy Artist', 'Professional', 'Contractor', 'Security Guard', 'Pediatrician',
    'Economist', 'Electrician Technician', 'Self-Employed Entrepreneur', 'Dealer', 'Civil Servant',
    'Actor', 'Advertising', 'Computer Science Graduate', 'Night Watchman', 'Private Employee',
    'Printer', 'Chemist', 'Mentor', 'Doctor', 'Mexican', 'French', 'American', 'Polish', 'Cuban', 'British',
    'Employee', 'Employee', 'Homemaker', 'Teacher', 'Designer', 'Secretary', 'Stylist', 'Teacher',
    'Accountant', 'Merchant', 'Housewife', 'Architect', 'Teacher', 'Graduate', 'Dentist', 'Nurse',
    'Businesswoman', 'Doctor', 'Journalist', 'Publicist', 'Dentist', 'Retired Teacher', 'Educator',
    'Professor', 'Psychologist', 'Public Accountant', 'Cashier', 'Government Employee', 'Administrator',
    'Dentist Surgeon', 'Singer', 'Lawyer', 'Preschool Teacher', 'Cook', 'Professional', 'Student',
    'Advisor', 'Chemist', 'Modest', 'Doctor', 'Engineer', 'Researcher', 'Beauty Therapist',
    'Graphic Designer', 'Promoter', 'Body Therapist', 'Chemical Engineer', 'Data Entry Operator',
    'Law Graduate', 'Communicologist', 'Seamstress', 'Pedagogue', 'Agronomist', 'Swimming Instructor',
    'Assistant', 'Biologist', 'Assistant', 'Marketing', 'Manager', 'Pensioner', 'Executive Assistant',
    'Elementary School Teacher', 'Restorer', 'Assistant', 'Director', 'Surgeon Doctor', 'Nutritionist',
    'Waitress', 'Musician', 'Sales Agent', 'Masters Degree', 'Consultant', 'Clinical Chemist',
    'Taxi Driver', 'Publicist', 'Technician', 'Federal Employee', 'Computer Science Graduate', 'Photographer',
    'Demo Specialist', 'Craftswoman', 'Homemaker', 'Podiatrist', 'Saleswoman', 'Civil Servant',
    'Languages Graduate', 'Academic', 'Public Servant', 'Mentor', 'Secondary School', 'High School',
    'Professional', 'Primary School', 'No Education', 'Other', 'Worker', 'Establishment', 'Employee',
    'Employer', 'Self-Employed Worker or Street Vendor', 'Unemployed', 'Works from Home',
    'Member of a Cooperative', 'Day Laborer', 'Secondary School', 'Professional', 'High School',
    'Primary School', 'Employee', 'Establishment', 'Unemployed', 'Employer',
    'Self-Employed Worker in the Street', 'Works from Home', 'Worker', 'Member of a Cooperative', 'Unpaid Worker'
]

# %%
mapping_dict = dict(zip(spanish, english))

# Replace the Spanish values with English values in the entire DataFrame
divorce_df = divorce_df.replace(mapping_dict)
divorce_df
# Out:
#         Id Divorce Date Divorce Type Nationality Male    DOB Male  Age Male  \
# 0        1       9/6/06    Necessary         American  1975/12/18      30.0
# 1        2       1/2/11    Necessary         American  2069/04/06      41.0
# 2        3       1/3/05    Necessary         American  2070/09/07      34.0
# 3        4       1/3/05    Necessary         American  1974/07/02      31.0
# 4        5       1/3/06    Necessary         American  2064/03/04      41.0
# ...    ...          ...          ...              ...         ...       ...
# 1370  1371     31/10/00    Voluntary         American  2059/03/09      41.0
# 1371  1372     31/10/01    Voluntary         American  2062/11/20      38.0
# 1372  1373     31/10/01    Voluntary         American  2058/04/07      43.0
# 1373  1374     31/10/02    Voluntary         American  2051/08/18      51.0
# 1374  1375     31/10/13    Voluntary         American  2054/10/28      59.0
#
# ...

# %%
columns = ['Id',
 'Divorce Date',
 'Divorce Type',
 'Nationality Male',
 'DOB Male',
 'Age Male',
 'Income Male',
 'Occupation Male',
 'Nationality Female',
 'DOB Female',
 'Age Female',
 'Occupation Female',
 'Income Female',
 'Marriage Date',
 'Education Male',
 'Employment Male',
 'Education Female',
 'Employment Female',
 'Marriage Year',
 'Number Children']

for col in columns:
    print(divorce_df[col].unique())
# Out:
# [   1    2    3 ... 1373 1374 1375]
# ['9/6/06' '1/2/11' '1/3/05' ... '31/10/01' '31/10/02' '31/10/13']
# ['Necessary' 'Voluntary']
# ['American' 'Polish' 'Cuban' 'Italian' 'German' 'Spanish']
# ['1975/12/18' '2069/04/06' '2070/09/07' ... '2058/04/07' '2051/08/18'
#  '2054/10/28']
# [30. 41. 34. 31. 37. 45. 33. 43. 53. 40. 35. 32. 36. 27. 38. 59. 64. 42.
#  47. 26. 24. 49. 39. 55. 50. 44. 51. 48. 63. 25. 54. 46. 29. 28. 52. 57.
#  56. 66. 61. 58. 67. 60. 62. 23. 70. 22. 69. 72. 20. 65. 21.]
# [2.000000e+03 5.000000e+03 5.600000e+03 3.500000e+03 1.200000e+04
#  6.000000e+03 1.400000e+04 1.000000e+04 8.000000e+03 2.200000e+03
#  3.000000e+03 3.900000e+03 2.500000e+04 6.500000e+03 8.400000e+03
#  9.000000e+03 1.000000e+03 2.400000e+03 4.000000e+03 1.800000e+04
#  2.500000e+03 7.000000e+03 1.500000e+04 4.123620e+05 2.000000e+04
#  1.900000e+04 4.000000e+04 1.560000e+04 5.400000e+03 3.000000e+04
#  2.240000e+03 1.600000e+04 4.800000e+03 1.085600e+04 4.500000e+03
# ...

# %%
spanish_2 = ['AUXILIAR CONTABLE', 'EMPLEADO DE PEMEX','LIC. EN EDUCACION' , 'REPRESENTANTE DE VENTAS', 'ARTE AUTOPCIA',
 'TECNICO ELECTRICISTA' , 'LIC.  INFORMATICA', 'FUNCIONARIO PRIVADO', 'LABORES DOMESTICAS','FUNCIONARIO PUBLICO','MENTORA', 'SECUNDARIA' , 
'JORNALERO O PEON', 'TRABAJADOR POR CUENTA PROPIA EN VIA PUBLICA ' ]
english_2 = ['Accounting Assistant', 'PEMEX Employee', 'Education Graduate', 'Sales Representative', 'Autopsy Artist',
'Electrician Technician', 'Computer Science Graduate', 'Private Employee', 'Homemaker', 'Public Servant', 'Mentor',
'Secondary School', 'Day Laborer', 'Self-Employed Worker in the Street']

mapping_dict_2 = dict(zip(spanish_2, english_2))

# Replace the Spanish values with English values in the entire DataFrame
divorce_df = divorce_df.replace(mapping_dict_2)

divorce_df.to_csv('divorce_df.csv', index=False)

# %%
divorce_df_copy=divorce_df.copy()
divorce_df_copy
# Out:
#         Id Divorce Date Divorce Type Nationality Male    DOB Male  Age Male  \
# 0        1       9/6/06    Necessary         American  1975/12/18      30.0
# 1        2       1/2/11    Necessary         American  2069/04/06      41.0
# 2        3       1/3/05    Necessary         American  2070/09/07      34.0
# 3        4       1/3/05    Necessary         American  1974/07/02      31.0
# 4        5       1/3/06    Necessary         American  2064/03/04      41.0
# ...    ...          ...          ...              ...         ...       ...
# 1370  1371     31/10/00    Voluntary         American  2059/03/09      41.0
# 1371  1372     31/10/01    Voluntary         American  2062/11/20      38.0
# 1372  1373     31/10/01    Voluntary         American  2058/04/07      43.0
# 1373  1374     31/10/02    Voluntary         American  2051/08/18      51.0
# 1374  1375     31/10/13    Voluntary         American  2054/10/28      59.0
#
# ...

# %%
divorce_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1375 entries, 0 to 1374
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  1375 non-null   int64
#  1   Divorce Date        1375 non-null   object
#  2   Divorce Type        1375 non-null   object
#  3   Nationality Male    1375 non-null   object
#  4   DOB Male            1375 non-null   object
#  5   Age Male            1375 non-null   float64
#  6   Income Male         1375 non-null   float64
#  7   Occupation Male     1375 non-null   object
#  8   Nationality Female  1375 non-null   object
#  9   DOB Female          1375 non-null   object
#  10  Age Female          1375 non-null   float64
#  11  Occupation Female   1375 non-null   object
#  12  Income Female       1375 non-null   float64
#  13  Marriage Date       1375 non-null   object
#  14  Education Male      1375 non-null   object
# ...

# %%
columns = ['Id',
 'Divorce Date',
 'Divorce Type',
 'Nationality Male',
 'DOB Male',
 'Age Male',
 'Income Male',
 'Occupation Male',
 'Nationality Female',
 'DOB Female',
 'Age Female',
 'Occupation Female',
 'Income Female',
 'Marriage Date',
 'Education Male',
 'Employment Male',
 'Education Female',
 'Employment Female',
 'Marriage Year',
 'Number Children']

for col in columns:
    print(divorce_df[col].unique())
# Out:
# [   1    2    3 ... 1373 1374 1375]
# ['9/6/06' '1/2/11' '1/3/05' ... '31/10/01' '31/10/02' '31/10/13']
# ['Necessary' 'Voluntary']
# ['American' 'Polish' 'Cuban' 'Italian' 'German' 'Spanish']
# ['1975/12/18' '2069/04/06' '2070/09/07' ... '2058/04/07' '2051/08/18'
#  '2054/10/28']
# [30. 41. 34. 31. 37. 45. 33. 43. 53. 40. 35. 32. 36. 27. 38. 59. 64. 42.
#  47. 26. 24. 49. 39. 55. 50. 44. 51. 48. 63. 25. 54. 46. 29. 28. 52. 57.
#  56. 66. 61. 58. 67. 60. 62. 23. 70. 22. 69. 72. 20. 65. 21.]
# [2.000000e+03 5.000000e+03 5.600000e+03 3.500000e+03 1.200000e+04
#  6.000000e+03 1.400000e+04 1.000000e+04 8.000000e+03 2.200000e+03
#  3.000000e+03 3.900000e+03 2.500000e+04 6.500000e+03 8.400000e+03
#  9.000000e+03 1.000000e+03 2.400000e+03 4.000000e+03 1.800000e+04
#  2.500000e+03 7.000000e+03 1.500000e+04 4.123620e+05 2.000000e+04
#  1.900000e+04 4.000000e+04 1.560000e+04 5.400000e+03 3.000000e+04
#  2.240000e+03 1.600000e+04 4.800000e+03 1.085600e+04 4.500000e+03
# ...

# %%
# Select columns in a list to include in male_df

selected_columns = ['Id', 'Divorce Date', 'Divorce Type', 'Nationality Male', 'DOB Male',
       'Age Male', 'Income Male', 'Occupation Male',
       'Marriage Date', 'Education Male', 'Employment Male', 'Marriage Year',
        'Number Children']

male_df = divorce_df[selected_columns].copy()
male_df.head()
# Out:
#    Id Divorce Date Divorce Type Nationality Male    DOB Male  Age Male  \
# 0   1       9/6/06    Necessary         American  1975/12/18      30.0
# 1   2       1/2/11    Necessary         American  2069/04/06      41.0
# 2   3       1/3/05    Necessary         American  2070/09/07      34.0
# 3   4       1/3/05    Necessary         American  1974/07/02      31.0
# 4   5       1/3/06    Necessary         American  2064/03/04      41.0
#
#    Income Male Occupation Male Marriage Date    Education Male  \
# 0       2000.0         Painter       26/6/00  Secondary School
# 1       5000.0       Architect        2/2/00       High School
# 2       5600.0          Driver       10/9/91  Secondary School
# 3       3500.0        Employer        1/2/93       High School
# 4      12000.0       Architect      12/11/98      Professional
#
#   Employment Male  Marriage Year  Number Children
# 0          Worker            5.0              1.0
# 1   Establishment            2.0              2.0
# ...

# %%
# Select columns in a list to include in female_df

selected_columns = ['Id', 'Divorce Date', 'Divorce Type', 'Nationality Female',
       'DOB Female', 'Age Female', 'Occupation Female', 'Income Female',
       'Marriage Date', 'Education Female', 'Employment Female', 'Marriage Year',
      'Number Children']

female_df = divorce_df[selected_columns].copy()
female_df.head()
# Out:
#    Id Divorce Date Divorce Type Nationality Female  DOB Female  Age Female  \
# 0   1       9/6/06    Necessary           American  1983/08/01        22.0
# 1   2       1/2/11    Necessary           American  2070/02/16        40.0
# 2   3       1/3/05    Necessary           American  2069/05/25        35.0
# 3   4       1/3/05    Necessary           American  2067/03/19        37.0
# 4   5       1/3/06    Necessary           American  1976/08/20        29.0
#
#   Occupation Female  Income Female Marriage Date  Education Female  \
# 0         Homemaker         1800.0       26/6/00  Secondary School
# 1         Homemaker         5000.0        2/2/00      Professional
# 2         Homemaker         4500.0       10/9/91  Secondary School
# 3          Employer         4000.0        1/2/93       High School
# 4         Homemaker         7000.0      12/11/98      Professional
#
#   Employment Female  Marriage Year  Number Children
# 0          Employer            5.0              1.0
# ...

# %%
def zodiac_sign(date_string):
    date = datetime.strptime(date_string, '%Y/%m/%d').date()
    month = date.month
    day = date.day
    
    if (month == 1 and day >= 20) or (month == 2 and day <= 18):
        return 'Aquarius'
    elif (month == 2 and day >= 19) or (month == 3 and day <= 20):
        return 'Pisces'
    elif (month == 3 and day >= 21) or (month == 4 and day <= 19):
        return 'Aries'
    elif (month == 4 and day >= 20) or (month == 5 and day <= 20):
        return 'Taurus'
    elif (month == 5 and day >= 21) or (month == 6 and day <= 20):
        return 'Gemini'
    elif (month == 6 and day >= 21) or (month == 7 and day <= 22):
        return 'Cancer'
    elif (month == 7 and day >= 23) or (month == 8 and day <= 22):
        return 'Leo'
    elif (month == 8 and day >= 23) or (month == 9 and day <= 22):
        return 'Virgo'
    elif (month == 9 and day >= 23) or (month == 10 and day <= 22):
        return 'Libra'
    elif (month == 10 and day >= 23) or (month == 11 and day <= 21):
        return 'Scorpio'
    elif (month == 11 and day >= 22) or (month == 12 and day <= 21):
        return 'Sagittarius'
    else:
        return 'Capricorn'

# Apply the zodiac_sign function to the DOB column and create a new column with the zodiac signs

zodiac_male = male_df.assign(Zodiac_Sign=male_df['DOB Male'].apply(zodiac_sign))
zodiac_sign = {'Zodiac_Sign':'Zodiac Sign'}
zodiac_male = zodiac_male.rename(columns=zodiac_sign)

zodiac_male
# Out:
#         Id Divorce Date Divorce Type Nationality Male    DOB Male  Age Male  \
# 0        1       9/6/06    Necessary         American  1975/12/18      30.0
# 1        2       1/2/11    Necessary         American  2069/04/06      41.0
# 2        3       1/3/05    Necessary         American  2070/09/07      34.0
# 3        4       1/3/05    Necessary         American  1974/07/02      31.0
# 4        5       1/3/06    Necessary         American  2064/03/04      41.0
# ...    ...          ...          ...              ...         ...       ...
# 1370  1371     31/10/00    Voluntary         American  2059/03/09      41.0
# 1371  1372     31/10/01    Voluntary         American  2062/11/20      38.0
# 1372  1373     31/10/01    Voluntary         American  2058/04/07      43.0
# 1373  1374     31/10/02    Voluntary         American  2051/08/18      51.0
# 1374  1375     31/10/13    Voluntary         American  2054/10/28      59.0
#
# ...

# %%
def zodiac_sign(date_string):
    date = datetime.strptime(date_string, '%Y/%m/%d').date()
    month = date.month
    day = date.day
    
    if (month == 1 and day >= 20) or (month == 2 and day <= 18):
        return 'Aquarius'
    elif (month == 2 and day >= 19) or (month == 3 and day <= 20):
        return 'Pisces'
    elif (month == 3 and day >= 21) or (month == 4 and day <= 19):
        return 'Aries'
    elif (month == 4 and day >= 20) or (month == 5 and day <= 20):
        return 'Taurus'
    elif (month == 5 and day >= 21) or (month == 6 and day <= 20):
        return 'Gemini'
    elif (month == 6 and day >= 21) or (month == 7 and day <= 22):
        return 'Cancer'
    elif (month == 7 and day >= 23) or (month == 8 and day <= 22):
        return 'Leo'
    elif (month == 8 and day >= 23) or (month == 9 and day <= 22):
        return 'Virgo'
    elif (month == 9 and day >= 23) or (month == 10 and day <= 22):
        return 'Libra'
    elif (month == 10 and day >= 23) or (month == 11 and day <= 21):
        return 'Scorpio'
    elif (month == 11 and day >= 22) or (month == 12 and day <= 21):
        return 'Sagittarius'
    else:
        return 'Capricorn'
# Apply the zodiac_sign function to the DOB column and create a new column with the zodiac signs

zodiac_female = female_df.assign(Zodiac_Sign=female_df['DOB Female'].apply(zodiac_sign))
zodiac_female.to_csv('zodiac_female.csv', index=False)

zodiac_female
# Out:
#         Id Divorce Date Divorce Type Nationality Female  DOB Female  \
# 0        1       9/6/06    Necessary           American  1983/08/01
# 1        2       1/2/11    Necessary           American  2070/02/16
# 2        3       1/3/05    Necessary           American  2069/05/25
# 3        4       1/3/05    Necessary           American  2067/03/19
# 4        5       1/3/06    Necessary           American  1976/08/20
# ...    ...          ...          ...                ...         ...
# 1370  1371     31/10/00    Voluntary           American  2056/07/09
# 1371  1372     31/10/01    Voluntary           American  2065/08/10
# 1372  1373     31/10/01    Voluntary           American  2058/03/26
# 1373  1374     31/10/02    Voluntary           American  2066/01/06
# 1374  1375     31/10/13    Voluntary           American  2057/02/17
#
#       Age Female Occupation Female  Income Female Marriage Date  \
# 0           22.0         Homemaker         1800.0       26/6/00
# ...
