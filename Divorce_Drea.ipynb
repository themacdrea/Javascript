# %%
import pandas as pd
from datetime import datetime

# %%
divorce_df = pd.read_csv("archive\divorces_2000-2015_translated.csv")

# %%
divorce_df
# Out:
#      Divorce_date Type_of_divorce Nationality_partner_man DOB_partner_man  \
# 0          9/6/06       Necesario                MEXICANA        18/12/75
# 1          1/2/00      Voluntario                MEXICANA             NaN
# 2          1/2/05       Necesario                MEXICANA         22/2/55
# 3          1/2/06       Necesario                MEXICANA         20/1/64
# 4          1/2/06       Necesario                MEXICANA        30/10/75
# ...           ...             ...                     ...             ...
# 4918     31/10/12      Voluntario                MEXICANA        29/10/77
# 4919     31/10/13      Voluntario                MEXICANA        10/11/82
# 4920     31/10/13      Voluntario                MEXICANA        28/10/54
# 4921     31/12/12      Voluntario                MEXICANA          7/2/58
# 4922     31/12/13      Voluntario                MEXICANA         22/6/60
#
#      Place_of_birth_partner_man Birth_municipality_of_partner_man  \
# 0             XALAPA - ENRIQUEZ                            XALAPA
# 1                           NaN                               NaN
# 2             XALAPA - ENRIQUEZ                            XALAPA
# 3             XALAPA - ENRIQUEZ                            XALAPA
# 4             XALAPA - ENRIQUEZ                            XALAPA
# ...                         ...                               ...
# 4918                    MORELIA                           MORELIA
# 4919                   VERACRUZ                          VERACRUZ
# 4920          XALAPA - ENRIQUEZ                            XALAPA
# 4921                 TLAPACOYAN                        TLAPACOYAN
# 4922                TLACOTALPAN                       TLACOTALPAN
#
#      Birth_federal_partner_man Birth_country_partner_man  Age_partner_man  \
# 0                     VERACRUZ                    MEXICO             30.0
# 1                          NaN                       NaN             47.0
# 2                     VERACRUZ                    MEXICO             49.0
# 3                     VERACRUZ                    MEXICO             42.0
# 4                     VERACRUZ                    MEXICO             30.0
# ...                        ...                       ...              ...
# 4918                 MICHOACAN                    MEXICO             35.0
# 4919                  VERACRUZ                    MEXICO             30.0
# 4920                  VERACRUZ                    MEXICO             59.0
# 4921                  VERACRUZ                    MEXICO             54.0
# 4922                  VERACRUZ                    MEXICO             53.0
#
#      Residence_municipality_partner_man  ...  \
# 0                                XALAPA  ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                XALAPA  ...
# 4                              COATEPEC  ...
# ...                                 ...  ...
# 4918                            MORELIA  ...
# 4919                             XALAPA  ...
# 4920                    EMILIANO ZAPATA  ...
# 4921                             XALAPA  ...
# 4922                             XALAPA  ...
#
#      Marriage_certificate_municipality Marriage_certificate_federal  \
# 0                               XALAPA                     VERACRUZ
# 1                               XALAPA                     VERACRUZ
# 2                               XALAPA                     VERACRUZ
# 3                               XALAPA                     VERACRUZ
# 4                               XALAPA                     VERACRUZ
# ...                                ...                          ...
# 4918                            XALAPA                     VERACRUZ
# 4919                            XALAPA                     VERACRUZ
# 4920                            XALAPA                     VERACRUZ
# 4921                        TLAPACOYAN                     VERACRUZ
# 4922                          COATEPEC                     VERACRUZ
#
#       Level_of_education_partner_man Employment_status_partner_man  \
# 0                         SECUNDARIA                        OBRERO
# 1                       PREPARATORIA               ESTABLECIMIENTO
# 2                       PREPARATORIA                        OBRERO
# 3                        PROFESIONAL                      EMPLEADO
# 4                        PROFESIONAL                      EMPLEADO
# ...                              ...                           ...
# 4918                     PROFESIONAL                      EMPLEADO
# 4919                     PROFESIONAL                      EMPLEADO
# 4920                     PROFESIONAL                      EMPLEADO
# 4921                    PREPARATORIA                           NaN
# 4922                     PROFESIONAL                      EMPLEADO
#
#      Level_of_education_partner_woman  \
# 0                          SECUNDARIA
# 1                        PREPARATORIA
# 2                                 NaN
# 3                        PREPARATORIA
# 4                        PREPARATORIA
# ...                               ...
# 4918                      PROFESIONAL
# 4919                      PROFESIONAL
# 4920                      PROFESIONAL
# 4921                         PRIMARIA
# 4922                      PROFESIONAL
#
#                    Employment_status_partner_woman Marriage_duration  \
# 0                                         EMPLEADO               5.0
# 1                                         EMPLEADO               NaN
# 2     TRABAJADOR POR CUENTA PROPIA EN VIA PUBLICA                NaN
# 3                                         EMPLEADO              18.0
# 4                                       NO TRABAJA               7.0
# ...                                            ...               ...
# 4918                                      EMPLEADO               3.0
# 4919                                      EMPLEADO               1.0
# 4920                                      EMPLEADO              35.0
# 4921                                    NO TRABAJA              33.0
# 4922                                      EMPLEADO               4.0
#
#      Marriage_duration_months Num_Children Custody
# 0                         NaN          1.0     NaN
# 1                         NaN          NaN     NaN
# 2                         NaN          NaN     NaN
# 3                         NaN          2.0   MADRE
# 4                         NaN          2.0   MADRE
# ...                       ...          ...     ...
# 4918                     11.0          NaN     NaN
# 4919                      NaN          NaN     NaN
# 4920                      NaN          2.0     NaN
# 4921                      NaN          2.0     NaN
# 4922                      NaN          NaN     NaN
#
# [4923 rows x 41 columns]

# %%
# Remove unwanted columns
remove = ['Place_of_birth_partner_man',
'Birth_municipality_of_partner_man',
'Birth_federal_partner_man',
'Birth_country_partner_man', 
'Residence_municipality_partner_man',
'Residence_federal_partner_man',
'Residence_country_partner_man',  
'Place_of_residence_partner_man',
'DOB_registration_date_partner_woman',
'Place_of_birth_partner_woman',
'Birth_municipality_of_partner_woman',
'Birth_federal_partner_woman',
'Birth_country_partner_woman',
'Place_of_residence_partner_woman',
'Residence_municipality_partner_woman',
'Residence_federal_partner_woman',
'Residence_country_partner_woman', 
'Marriage_certificate_place',
'Marriage_certificate_municipality',
'Marriage_certificate_federal']

divorce_df = divorce_df.drop(columns=remove)
divorce_df.head()
# Out:
#   Divorce_date Type_of_divorce Nationality_partner_man DOB_partner_man  \
# 0       9/6/06       Necesario                MEXICANA        18/12/75
# 1       1/2/00      Voluntario                MEXICANA             NaN
# 2       1/2/05       Necesario                MEXICANA         22/2/55
# 3       1/2/06       Necesario                MEXICANA         20/1/64
# 4       1/2/06       Necesario                MEXICANA        30/10/75
#
#    Age_partner_man  Monthly_income_partner_man_peso Occupation_partner_man  \
# 0             30.0                           2000.0                 PINTOR
# 1             47.0                              NaN                    NaN
# 2             49.0                              NaN                 MEDICO
# 3             42.0                           6000.0               EMPLEADO
# 4             30.0                          18000.0                 MEDICO
#
#   Nationality_partner_woman DOB_partner_woman  Age_partner_woman  ...  \
# 0                  MEXICANA            8/1/83               22.0  ...
# 1                  MEXICANA               NaN               41.0  ...
# 2                  MEXICANA           21/3/47               57.0  ...
# 3                  MEXICANA               NaN                NaN  ...
# 4                  MEXICANA          13/10/78               27.0  ...
#
#   Monthly_income_partner_woman_peso  Date_of_marriage  \
# 0                            1800.0           26/6/00
# 1                               NaN           17/2/77
# 2                               NaN          18/12/75
# 3                            5000.0           3/12/87
# 4                               NaN          14/11/98
#
#   Level_of_education_partner_man Employment_status_partner_man  \
# 0                     SECUNDARIA                        OBRERO
# 1                   PREPARATORIA               ESTABLECIMIENTO
# 2                   PREPARATORIA                        OBRERO
# 3                    PROFESIONAL                      EMPLEADO
# 4                    PROFESIONAL                      EMPLEADO
#
#   Level_of_education_partner_woman  \
# 0                       SECUNDARIA
# 1                     PREPARATORIA
# 2                              NaN
# 3                     PREPARATORIA
# 4                     PREPARATORIA
#
#                 Employment_status_partner_woman Marriage_duration  \
# 0                                      EMPLEADO               5.0
# 1                                      EMPLEADO               NaN
# 2  TRABAJADOR POR CUENTA PROPIA EN VIA PUBLICA                NaN
# 3                                      EMPLEADO              18.0
# 4                                    NO TRABAJA               7.0
#
#    Marriage_duration_months  Num_Children  Custody
# 0                       NaN           1.0      NaN
# 1                       NaN           NaN      NaN
# 2                       NaN           NaN      NaN
# 3                       NaN           2.0    MADRE
# 4                       NaN           2.0    MADRE
#
# [5 rows x 21 columns]

# %%
# Create a new column with id number 
divorce_df.insert(0, 'Id', range(1, len(divorce_df)+1))
divorce_df.head()
# Out:
#    Id Divorce_date Type_of_divorce Nationality_partner_man DOB_partner_man  \
# 0   1       9/6/06       Necesario                MEXICANA        18/12/75
# 1   2       1/2/00      Voluntario                MEXICANA             NaN
# 2   3       1/2/05       Necesario                MEXICANA         22/2/55
# 3   4       1/2/06       Necesario                MEXICANA         20/1/64
# 4   5       1/2/06       Necesario                MEXICANA        30/10/75
#
#    Age_partner_man  Monthly_income_partner_man_peso Occupation_partner_man  \
# 0             30.0                           2000.0                 PINTOR
# 1             47.0                              NaN                    NaN
# 2             49.0                              NaN                 MEDICO
# 3             42.0                           6000.0               EMPLEADO
# 4             30.0                          18000.0                 MEDICO
#
#   Nationality_partner_woman DOB_partner_woman  ...  \
# 0                  MEXICANA            8/1/83  ...
# 1                  MEXICANA               NaN  ...
# 2                  MEXICANA           21/3/47  ...
# 3                  MEXICANA               NaN  ...
# 4                  MEXICANA          13/10/78  ...
#
#    Monthly_income_partner_woman_peso Date_of_marriage  \
# 0                             1800.0          26/6/00
# 1                                NaN          17/2/77
# 2                                NaN         18/12/75
# 3                             5000.0          3/12/87
# 4                                NaN         14/11/98
#
#    Level_of_education_partner_man Employment_status_partner_man  \
# 0                      SECUNDARIA                        OBRERO
# 1                    PREPARATORIA               ESTABLECIMIENTO
# 2                    PREPARATORIA                        OBRERO
# 3                     PROFESIONAL                      EMPLEADO
# 4                     PROFESIONAL                      EMPLEADO
#
#   Level_of_education_partner_woman  \
# 0                       SECUNDARIA
# 1                     PREPARATORIA
# 2                              NaN
# 3                     PREPARATORIA
# 4                     PREPARATORIA
#
#                 Employment_status_partner_woman Marriage_duration  \
# 0                                      EMPLEADO               5.0
# 1                                      EMPLEADO               NaN
# 2  TRABAJADOR POR CUENTA PROPIA EN VIA PUBLICA                NaN
# 3                                      EMPLEADO              18.0
# 4                                    NO TRABAJA               7.0
#
#   Marriage_duration_months  Num_Children  Custody
# 0                      NaN           1.0      NaN
# 1                      NaN           NaN      NaN
# 2                      NaN           NaN      NaN
# 3                      NaN           2.0    MADRE
# 4                      NaN           2.0    MADRE
#
# [5 rows x 22 columns]

# %%
#Rename columns
column_names = {
    'Divorce_date': 'Divorce Date',
    'Type_of_divorce': 'Divorce Type',
    'Nationality_partner_man': 'Nationality Male',
    'DOB_partner_man': 'DOB Male',
    'Age_partner_man': 'Age Male',
    'Monthly_income_partner_man_peso': 'Income Male',
    'Occupation_partner_man': 'Occupation Male',
    'Nationality_partner_woman': 'Nationality Female',
    'DOB_partner_woman': 'DOB Female',
    'Age_partner_woman': 'Age Female',
    'Occupation_partner_woman': 'Occupation Female',
    'Monthly_income_partner_woman_peso': 'Income Female',
    'Date_of_marriage': 'Marriage Date',
    'Level_of_education_partner_man': 'Education Male',
    'Employment_status_partner_man': 'Employment Male',
    'Level_of_education_partner_woman': 'Education Female',
    'Employment_status_partner_woman': 'Employment Female',
    'Marriage_duration': 'Marriage Year',
    'Marriage_duration_months': 'Marriage Months',
    'Num_Children': 'Number Children',
    'Custody': 'Custody'
}

divorce_df = divorce_df.rename(columns=column_names)
divorce_df.head()
# Out:
#    Id Divorce Date Divorce Type Nationality Male  DOB Male  Age Male  \
# 0   1       9/6/06    Necesario         MEXICANA  18/12/75      30.0
# 1   2       1/2/00   Voluntario         MEXICANA       NaN      47.0
# 2   3       1/2/05    Necesario         MEXICANA   22/2/55      49.0
# 3   4       1/2/06    Necesario         MEXICANA   20/1/64      42.0
# 4   5       1/2/06    Necesario         MEXICANA  30/10/75      30.0
#
#    Income Male Occupation Male Nationality Female DOB Female  ...  \
# 0       2000.0          PINTOR           MEXICANA     8/1/83  ...
# 1          NaN             NaN           MEXICANA        NaN  ...
# 2          NaN          MEDICO           MEXICANA    21/3/47  ...
# 3       6000.0        EMPLEADO           MEXICANA        NaN  ...
# 4      18000.0          MEDICO           MEXICANA   13/10/78  ...
#
#    Income Female Marriage Date  Education Male  Employment Male  \
# 0         1800.0       26/6/00      SECUNDARIA           OBRERO
# 1            NaN       17/2/77    PREPARATORIA  ESTABLECIMIENTO
# 2            NaN      18/12/75    PREPARATORIA           OBRERO
# 3         5000.0       3/12/87     PROFESIONAL         EMPLEADO
# 4            NaN      14/11/98     PROFESIONAL         EMPLEADO
#
#   Education Female                             Employment Female  \
# 0       SECUNDARIA                                      EMPLEADO
# 1     PREPARATORIA                                      EMPLEADO
# 2              NaN  TRABAJADOR POR CUENTA PROPIA EN VIA PUBLICA
# 3     PREPARATORIA                                      EMPLEADO
# 4     PREPARATORIA                                    NO TRABAJA
#
#   Marriage Year Marriage Months  Number Children  Custody
# 0           5.0             NaN              1.0      NaN
# 1           NaN             NaN              NaN      NaN
# 2           NaN             NaN              NaN      NaN
# 3          18.0             NaN              2.0    MADRE
# 4           7.0             NaN              2.0    MADRE
#
# [5 rows x 22 columns]

# %%
divorce_df['DOB Male'] = pd.to_datetime(divorce_df['DOB Male'])

# Clean up the DOB column to the format 'y/m/d'
divorce_df['DOB Male'] = divorce_df['DOB Male'].dt.strftime('%Y/%m/%d')

drop_null_male = 'DOB Male'
divorce_df.dropna(subset=[drop_null_male], inplace=True)

divorce_df['DOB Female'] = pd.to_datetime(divorce_df['DOB Female'])

# Clean up the DOB column to the format 'y/m/d'
divorce_df['DOB Female'] = divorce_df['DOB Female'].dt.strftime('%Y/%m/%d')

drop_null_female = 'DOB Female'
divorce_df.dropna(subset=[drop_null_female], inplace=True)

# %%
# Select columns in a list to include in male_df

selected_columns = ['Id', 'Divorce Date', 'Divorce Type', 'Nationality Male', 'DOB Male',
       'Age Male', 'Income Male', 'Occupation Male',
       'Marriage Date', 'Education Male', 'Employment Male', 'Marriage Year',
       'Marriage Months', 'Number Children', 'Custody'
]

male_df = divorce_df[selected_columns].copy()
male_df.head()
# Out:
#    Id Divorce Date Divorce Type Nationality Male    DOB Male  Age Male  \
# 0   1       9/6/06    Necesario         MEXICANA  1975/12/18      30.0
# 2   3       1/2/05    Necesario         MEXICANA  2055/02/22      49.0
# 4   5       1/2/06    Necesario         MEXICANA  1975/10/30      30.0
# 5   6       1/2/06    Necesario         MEXICANA  1973/03/28      32.0
# 6   7       1/2/07    Necesario         MEXICANA  2070/12/13      36.0
#
#    Income Male Occupation Male Marriage Date Education Male Employment Male  \
# 0       2000.0          PINTOR       26/6/00     SECUNDARIA          OBRERO
# 2          NaN          MEDICO      18/12/75   PREPARATORIA          OBRERO
# 4      18000.0          MEDICO      14/11/98    PROFESIONAL        EMPLEADO
# 5          NaN        EMPLEADO       20/1/95     SECUNDARIA        EMPLEADO
# 6          NaN        EMPLEADO       16/8/91    PROFESIONAL        EMPLEADO
#
#    Marriage Year  Marriage Months  Number Children Custody
# 0            5.0              NaN              1.0     NaN
# 2            NaN              NaN              NaN     NaN
# 4            7.0              NaN              2.0   MADRE
# 5           11.0              NaN              2.0   MADRE
# 6           15.0              NaN              2.0   MADRE

# %%
# Select columns in a list to include in female_df

selected_columns = ['Id', 'Divorce Date', 'Divorce Type', 'Nationality Female',
       'DOB Female', 'Age Female', 'Occupation Female', 'Income Female',
       'Marriage Date', 'Education Female', 'Employment Female', 'Marriage Year',
       'Marriage Months', 'Number Children', 'Custody']

female_df = divorce_df[selected_columns].copy()
female_df.head()
# Out:
#    Id Divorce Date Divorce Type Nationality Female  DOB Female  Age Female  \
# 0   1       9/6/06    Necesario           MEXICANA  1983/08/01        22.0
# 2   3       1/2/05    Necesario           MEXICANA  2047/03/21        57.0
# 4   5       1/2/06    Necesario           MEXICANA  1978/10/13        27.0
# 5   6       1/2/06    Necesario           MEXICANA  1976/06/14        29.0
# 6   7       1/2/07    Necesario           MEXICANA  2071/04/11        35.0
#
#     Occupation Female  Income Female Marriage Date Education Female  \
# 0            EMPLEADA         1800.0       26/6/00       SECUNDARIA
# 2            JUBILADA            NaN      18/12/75              NaN
# 4         AMA DE CASA            NaN      14/11/98     PREPARATORIA
# 5                 NaN            NaN       20/1/95       SECUNDARIA
# 6  LABORES DOMESTICAS            NaN       16/8/91      PROFESIONAL
#
#                               Employment Female  Marriage Year  \
# 0                                      EMPLEADO            5.0
# 2  TRABAJADOR POR CUENTA PROPIA EN VIA PUBLICA             NaN
# 4                                    NO TRABAJA            7.0
# 5                                    NO TRABAJA           11.0
# 6                                    NO TRABAJA           15.0
#
#    Marriage Months  Number Children Custody
# 0              NaN              1.0     NaN
# 2              NaN              NaN     NaN
# 4              NaN              2.0   MADRE
# 5              NaN              2.0   MADRE
# 6              NaN              2.0   MADRE

# %%
def zodiac_sign(date_string):
    date = datetime.strptime(date_string, '%Y/%m/%d').date()
    month = date.month
    day = date.day
    
    if (month == 1 and day >= 20) or (month == 2 and day <= 18):
        return 'Aquarius'
    elif (month == 2 and day >= 19) or (month == 3 and day <= 20):
        return 'Pisces'
    elif (month == 3 and day >= 21) or (month == 4 and day <= 19):
        return 'Aries'
    elif (month == 4 and day >= 20) or (month == 5 and day <= 20):
        return 'Taurus'
    elif (month == 5 and day >= 21) or (month == 6 and day <= 20):
        return 'Gemini'
    elif (month == 6 and day >= 21) or (month == 7 and day <= 22):
        return 'Cancer'
    elif (month == 7 and day >= 23) or (month == 8 and day <= 22):
        return 'Leo'
    elif (month == 8 and day >= 23) or (month == 9 and day <= 22):
        return 'Virgo'
    elif (month == 9 and day >= 23) or (month == 10 and day <= 22):
        return 'Libra'
    elif (month == 10 and day >= 23) or (month == 11 and day <= 21):
        return 'Scorpio'
    elif (month == 11 and day >= 22) or (month == 12 and day <= 21):
        return 'Sagittarius'
    else:
        return 'Capricorn'

# Apply the get_zodiac_sign function to the DOB column and create a new column with the zodiac signs

zodiac_male = male_df.assign(Zodiac_Sign=male_df['DOB Male'].apply(zodiac_sign))
zodiac_sign = {'Zodiac_Sign':'Zodiac Sign'}
zodiac_male = zodiac_male.rename(columns=zodiac_sign)

zodiac_male
# Out:
#         Id Divorce Date Divorce Type Nationality Male    DOB Male  Age Male  \
# 0        1       9/6/06    Necesario         MEXICANA  1975/12/18      30.0
# 2        3       1/2/05    Necesario         MEXICANA  2055/02/22      49.0
# 4        5       1/2/06    Necesario         MEXICANA  1975/10/30      30.0
# 5        6       1/2/06    Necesario         MEXICANA  1973/03/28      32.0
# 6        7       1/2/07    Necesario         MEXICANA  2070/12/13      36.0
# ...    ...          ...          ...              ...         ...       ...
# 4918  4919     31/10/12   Voluntario         MEXICANA  1977/10/29      35.0
# 4919  4920     31/10/13   Voluntario         MEXICANA  1982/10/11      30.0
# 4920  4921     31/10/13   Voluntario         MEXICANA  2054/10/28      59.0
# 4921  4922     31/12/12   Voluntario         MEXICANA  2058/07/02      54.0
# 4922  4923     31/12/13   Voluntario         MEXICANA  2060/06/22      53.0
#
#       Income Male Occupation Male Marriage Date Education Male  \
# 0          2000.0          PINTOR       26/6/00     SECUNDARIA
# 2             NaN          MEDICO      18/12/75   PREPARATORIA
# 4         18000.0          MEDICO      14/11/98    PROFESIONAL
# 5             NaN        EMPLEADO       20/1/95     SECUNDARIA
# 6             NaN        EMPLEADO       16/8/91    PROFESIONAL
# ...           ...             ...           ...            ...
# 4918      12500.0         AUDITOR      25/10/08    PROFESIONAL
# 4919          NaN        EMPLEADO       26/5/12    PROFESIONAL
# 4920      20000.0          MEDICO        2/6/78    PROFESIONAL
# 4921          NaN        EMPLEADO       5/11/79   PREPARATORIA
# 4922      20000.0        CONTADOR       22/8/09    PROFESIONAL
#
#      Employment Male  Marriage Year  Marriage Months  Number Children Custody  \
# 0             OBRERO            5.0              NaN              1.0     NaN
# 2             OBRERO            NaN              NaN              NaN     NaN
# 4           EMPLEADO            7.0              NaN              2.0   MADRE
# 5           EMPLEADO           11.0              NaN              2.0   MADRE
# 6           EMPLEADO           15.0              NaN              2.0   MADRE
# ...              ...            ...              ...              ...     ...
# 4918        EMPLEADO            3.0             11.0              NaN     NaN
# 4919        EMPLEADO            1.0              NaN              NaN     NaN
# 4920        EMPLEADO           35.0              NaN              2.0     NaN
# 4921             NaN           33.0              NaN              2.0     NaN
# 4922        EMPLEADO            4.0              NaN              NaN     NaN
#
#       Zodiac Sign  Zodiac Sign
# 0     Sagittarius  Sagittarius
# 2          Pisces       Pisces
# 4         Scorpio      Scorpio
# 5           Aries        Aries
# 6     Sagittarius  Sagittarius
# ...           ...          ...
# 4918      Scorpio      Scorpio
# 4919        Libra        Libra
# 4920      Scorpio      Scorpio
# 4921       Cancer       Cancer
# 4922       Cancer       Cancer
#
# [4374 rows x 17 columns]

# %%
def zodiac_sign(date_string):
    date = datetime.strptime(date_string, '%Y/%m/%d').date()
    month = date.month
    day = date.day
    
    if (month == 1 and day >= 20) or (month == 2 and day <= 18):
        return 'Aquarius'
    elif (month == 2 and day >= 19) or (month == 3 and day <= 20):
        return 'Pisces'
    elif (month == 3 and day >= 21) or (month == 4 and day <= 19):
        return 'Aries'
    elif (month == 4 and day >= 20) or (month == 5 and day <= 20):
        return 'Taurus'
    elif (month == 5 and day >= 21) or (month == 6 and day <= 20):
        return 'Gemini'
    elif (month == 6 and day >= 21) or (month == 7 and day <= 22):
        return 'Cancer'
    elif (month == 7 and day >= 23) or (month == 8 and day <= 22):
        return 'Leo'
    elif (month == 8 and day >= 23) or (month == 9 and day <= 22):
        return 'Virgo'
    elif (month == 9 and day >= 23) or (month == 10 and day <= 22):
        return 'Libra'
    elif (month == 10 and day >= 23) or (month == 11 and day <= 21):
        return 'Scorpio'
    elif (month == 11 and day >= 22) or (month == 12 and day <= 21):
        return 'Sagittarius'
    else:
        return 'Capricorn'
# Apply the get_zodiac_sign function to the DOB column and create a new column with the zodiac signs

zodiac_female = female_df.assign(Zodiac_Sign=female_df['DOB Female'].apply(zodiac_sign))
zodiac_female.to_csv('zodiac_female.csv', index=False)

zodiac_female
# Out:
#         Id Divorce Date Divorce Type Nationality Female  DOB Female  \
# 0        1       9/6/06    Necesario           MEXICANA  1983/08/01
# 2        3       1/2/05    Necesario           MEXICANA  2047/03/21
# 4        5       1/2/06    Necesario           MEXICANA  1978/10/13
# 5        6       1/2/06    Necesario           MEXICANA  1976/06/14
# 6        7       1/2/07    Necesario           MEXICANA  2071/04/11
# ...    ...          ...          ...                ...         ...
# 4918  4919     31/10/12   Voluntario           MEXICANA  1978/12/01
# 4919  4920     31/10/13   Voluntario           MEXICANA  1981/09/02
# 4920  4921     31/10/13   Voluntario           MEXICANA  2057/02/17
# 4921  4922     31/12/12   Voluntario           MEXICANA  2064/01/27
# 4922  4923     31/12/13   Voluntario           MEXICANA  2072/01/22
#
#       Age Female   Occupation Female  Income Female Marriage Date  \
# 0           22.0            EMPLEADA         1800.0       26/6/00
# 2           57.0            JUBILADA            NaN      18/12/75
# 4           27.0         AMA DE CASA            NaN      14/11/98
# 5           29.0                 NaN            NaN       20/1/95
# 6           35.0  LABORES DOMESTICAS            NaN       16/8/91
# ...          ...                 ...            ...           ...
# 4918        34.0            EMPLEADA         6000.0      25/10/08
# 4919        32.0            EMPLEADA            NaN       26/5/12
# 4920        56.0            JUBILADA        29000.0        2/6/78
# 4921        48.0         AMA DE CASA            NaN       5/11/79
# 4922        41.0          ARQUITECTA        20000.0       22/8/09
#
#      Education Female                             Employment Female  \
# 0          SECUNDARIA                                      EMPLEADO
# 2                 NaN  TRABAJADOR POR CUENTA PROPIA EN VIA PUBLICA
# 4        PREPARATORIA                                    NO TRABAJA
# 5          SECUNDARIA                                    NO TRABAJA
# 6         PROFESIONAL                                    NO TRABAJA
# ...               ...                                           ...
# 4918      PROFESIONAL                                      EMPLEADO
# 4919      PROFESIONAL                                      EMPLEADO
# 4920      PROFESIONAL                                      EMPLEADO
# 4921         PRIMARIA                                    NO TRABAJA
# 4922      PROFESIONAL                                      EMPLEADO
#
#       Marriage Year  Marriage Months  Number Children Custody  Zodiac Sign  \
# 0               5.0              NaN              1.0     NaN          Leo
# 2               NaN              NaN              NaN     NaN        Aries
# 4               7.0              NaN              2.0   MADRE        Libra
# 5              11.0              NaN              2.0   MADRE       Gemini
# 6              15.0              NaN              2.0   MADRE        Aries
# ...             ...              ...              ...     ...          ...
# 4918            3.0             11.0              NaN     NaN  Sagittarius
# 4919            1.0              NaN              NaN     NaN        Virgo
# 4920           35.0              NaN              2.0     NaN     Aquarius
# 4921           33.0              NaN              2.0     NaN     Aquarius
# 4922            4.0              NaN              NaN     NaN     Aquarius
#
#       Zodiac_Sign
# 0             Leo
# 2           Aries
# 4           Libra
# 5          Gemini
# 6           Aries
# ...           ...
# 4918  Sagittarius
# 4919        Virgo
# 4920     Aquarius
# 4921     Aquarius
# 4922     Aquarius
#
# [4374 rows x 17 columns]
